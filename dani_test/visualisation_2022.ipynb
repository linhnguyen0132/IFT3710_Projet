# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_2022_obs = pd.read_csv("C:/Users/danid/OneDrive/Documents/Math&info/projet_apprentissage/observations_2022/observations_fr_train.csv", sep=";")
data_2022_obs.head(5)
data_2022_obs.columns
# Out:
# Index(['observation_id', 'latitude', 'longitude', 'species_id', 'subset'], dtype='object')

# %%
# Enlever les nans
data_2022_obs = data_2022_obs.dropna()
len(data_2022_obs)
# Out:
# 671244

# %%
# Visualiser les données avec seaborn 
# Plus spécifiquement nous voulons regarder le nombre d'occurence de chaque espèce
plt.figure(figsize=(6, 4))
sns.histplot(data=data_2022_obs, x="species_id")
plt.tight_layout()
plt.show()

# Interprétation : Nous voyons que les données de France de 2022 présentent un left-skew.
